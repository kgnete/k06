# %% [markdown]
# * [INDICE](0-indice.ipynb)
#
#
# Complete Wiring vertical1
#  Marcar esta página
# In this step, we will use jumper wires to connect the Arduino's , , ,  and  signals to the circuit board. The connections are detailed in Figure 44, which shows the following connections:
#
# Arduino analog input  should be connected to the filtered angle sensor output – yellow (A0, a16)
#
# Arduino analog input  should be connected to the filtered motor voltage – blue (A1, a20)
#
# Arduino PWM output  should be connected to the  resistor (whose other end is connected to the base of the motor driver transistor) – purple (D9, g23)
#
# To supply power to the sensor, one of the Arduino's grounds, labeled , should be connected to the circuit board's left side ground – teal (GND, -16.5L)
#
# Arduino's  should be circuit board positive – red (5V, +16.5L)
#
#
# Figure 44: Connections between the circuit board, the Arduino and the copter motor.
# NOTE: The circuit board connections for the propellor motor jumper wires are also shown in Figure 44, but do not connect them yet. You will
#
# ![Screenshot%20from%202019-04-24%2011-50-36.png](attachment:Screenshot%20from%202019-04-24%2011-50-36.png)
