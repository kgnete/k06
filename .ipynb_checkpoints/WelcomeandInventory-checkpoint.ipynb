# %% [markdown]
# * [INDICE](0-indice.ipynb)
#
#
# The first step in building your copter is to lay out all of your parts and make sure you have everything ready to go. Here are the parts you should have received from amazon and digi-key:
#
#
# ![Screenshot%20from%202019-04-24%2011-42-38.png](attachment:Screenshot%20from%202019-04-24%2011-42-38.png)
# (4) 22μF capacitors
#
# (1) assembly box
#
# (1) quadcopter
#
# (1) breadboard
#
# (1) USB cable
#
# (1) Arduino
#
# (1) set of male-to-male jumper wires
#
# (1) pre-stripped wire kit
#
# (1) bag of orthodontics rubber bands
#
# (1) 5V DC power supply
#
# (1) No.2 pencil
#
# (3) 1k resistors
#
# (2) 1 resistors
#
# (1) hall effect sensor
#
# (1) transistor
#
# (1) DC connection jack
#
# It may also help to have needle-nose plyers and wire cutters, but there are other tools that can be used to accomplish the same tasks, if you do not happen to have these laying around.
#
# The inventory is shown in Figure 2.
#
# ![Screenshot%20from%202019-04-24%2011-43-21.png](attachment:Screenshot%20from%202019-04-24%2011-43-21.png)
# Figure 2: Inventory for the copter assembly.
# For those of you who are comfortable reading circuit schematics (not required!) and you wish to wire the circuit yourself, the schematic is shown in Figure 3.
#
# ![Screenshot%20from%202019-04-24%2011-44-15.png](attachment:Screenshot%20from%202019-04-24%2011-44-15.png)
# Figure 3: Copter circuit schematic.
# If you are not comfortable with schematics (have no fear!) we will work through the wiring process together step by step. You may wish to refer back to the schematic at the end to understand more completely what you have done.
