# %% [markdown]
# * [0-indice](0-indice.ipynb)
# # [CopterAssemblyGuide](CopterAssemblyGuide.ipynb)
# * [WelcomeandInventory](WelcomeandInventory.ipynb)
# * [WireBreadboard](WireBreadboard.ipynb)
# * [WireAngleSensor](WireAngleSensor.ipynb)
# * [PreparePropellerArm](PreparePropellerArm.ipynb)
# * [ModifyAssemblyBox](ModifyAssemblyBox.ipynb)
# * [InstallBreadboardandSensor](InstallBreadboardandSensor.ipynb)
# * [AttachPropellerArm](AttachPropellerArm.ipynb)
# * [CompleteWiring](CompleteWiring.ipynb)
# * [ClassSurvey](ClassSurvey.ipynb)
# # [SoftwareGuide](SoftwareGuide.ipynb)
# * [SoftwareIntroduction](SoftwareIntroduction.ipynb)
# * [GettingStarted](GettingStarted.ipynb)
# * [Arduino(AllOS's)](Arduino(AllOS's).ipynb)
# * [PythonInstall(Windows)](PythonInstall(Windows).ipynb)
# * [PythonInstall(Mac)](PythonInstall(Mac).ipynb)
# * [PythonInstall(Nix)](PythonInstall(Nix).ipynb)
# * [HowtoUsetheGUI](HowtoUsetheGUI.ipynb)
# # [IntroductiontoSequencesandDifferenceEquations](IntroductiontoSequencesandDifferenceEquations.ipynb)
# * [Overview](Overview.ipynb)
# * [Sequences](Sequences.ipynb)
# * [LinearDifferenceEquations(LDEs)](LinearDifferenceEquations(LDEs).ipynb)
# * [First-OrderHomogeneousLDEs](First-OrderHomogeneousLDEs.ipynb)
# * [Second-OrderHomogeneousLDEs](Second-OrderHomogeneousLDEs.ipynb)
# * [Higher-OrderHomogeneousLDEs](Higher-OrderHomogeneousLDEs.ipynb)
# * [CraneMutiny](CraneMutiny.ipynb)
# * [ProblemSet1](ProblemSet1.ipynb)
# * [Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# * [Lab1](Lab1.ipynb)
# * [Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# # [Week2-ProportionalControl](Week2-ProportionalControl.ipynb)
# ## [Lecture2](Lecture2.ipynb)
# * [Lecture2-PDFHandout](Lecture2-PDFHandout.ipynb)
# ## [ProblemSet2](ProblemSet2.ipynb)
# * [Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# * [DifferenceEquationPracticeI](DifferenceEquationPracticeI.ipynb)
# * [DifferenceEquationPracticeII](DifferenceEquationPracticeII.ipynb)
# * [FirstOrderEquationswithInputsandNaturalFrequencies](FirstOrderEquationswithInputsandNaturalFrequencies.ipynb)
# * [FeedbackSystems](FeedbackSystems.ipynb)
# * [FeedbackSystemswithDisturbances](FeedbackSystemswithDisturbances.ipynb)
# ## [Lab2](Lab2.ipynb)
# * [Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# * [Lab2Introduction](Lab2Introduction.ipynb)
# * [Lab2SoftwareandHardware](Lab2SoftwareandHardware.ipynb)
# * [BriefTutorial](BriefTutorial.ipynb)
# * [TheExperiment](TheExperiment.ipynb)
# * [LabQuestions](LabQuestions.ipynb)
# # [Week3-PDControl](Week3-PDControl.ipynb)
# ## [Lecture3](Lecture3.ipynb)
# * [Summary](Summary.ipynb)
# * [FanController](FanController.ipynb)
# * [TheCraneYetAgain](TheCraneYetAgain.ipynb)
# ## [ProblemSet3](ProblemSet3.ipynb)
# * [Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Problem_Setfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# * [SolvingForCoefficients](SolvingForCoefficients.ipynb)
# * [NaturalFrequencies](NaturalFrequencies.ipynb)
# * [NaturalFrequenciesII](NaturalFrequenciesII.ipynb)
# * [NaturalFrequenciesIII](NaturalFrequenciesIII.ipynb)
# * [HelicopterSimulationI](HelicopterSimulationI.ipynb)
# * [HelicopterSimII](HelicopterSimII.ipynb)
# * [HelicopterSimIII](HelicopterSimIII.ipynb)
# * [HelicopterSimIV](HelicopterSimIV.ipynb)
# * [HelicopterSimV(Extra)](HelicopterSimV(Extra).ipynb)
# ## [Lab3](Lab3.ipynb)
# * [Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable](Labfechalímite1defeb.de201606:00CETEstecontenidoescalificable.ipynb)
# * [BackgroundCopterPhysics](BackgroundCopterPhysics.ipynb)
# * [BackgroundProportionalControl](BackgroundProportionalControl.ipynb)
# * [BackgroundonPDControl](BackgroundonPDControl.ipynb)
# * [SoftwareSetup](SoftwareSetup.ipynb)
# * [TheExperiment](TheExperiment.ipynb)
# * [Questions](Questions.ipynb)
# ## [RootFinder!](RootFinder!.ipynb)
# * [Utility](Utility.ipynb)
# # [CourseSurveys](CourseSurveys.ipynb)
# ## [EntranceSurvey](EntranceSurvey.ipynb)
# * [Survey](Survey.ipynb)
# ## [ExitSurvey](ExitSurvey.ipynb)
# * [Survey](Survey.ipynb)
